# %% [markdown]
# # irp-dbk24 - "Optimising Demand Response Strategies for Carbon-Intelligent Electricity Use"

# %% [markdown]
# # Investigating ERA5 World Data

# %% [markdown]
# **NOTEBOOK PURPOSE(S):**
# * Investigate structure and contents of data retrieved from the ERA5 World dataset.
#
# **NOTEBOOK OUTPUTS:**
# * N/A

# %% [markdown]
# ### Importing Libraries

# %%
# %matplotlib inline

# ────────────────────────────────────────────────────────────────────────────
# Data Manipulation & Analysis
# ─────────────────────────────────────────────────────────────────────────────
import pandas as pd
import numpy as np

# ─────────────────────────────────────────────────────────────────────────────
# Geospatial Data Handling
# ─────────────────────────────────────────────────────────────────────────────
import xarray as xr
import cfgrib
import pygrib

# ─────────────────────────────────────────────────────────────────────────────
# Notebook/Display Tools
# ─────────────────────────────────────────────────────────────────────────────
from IPython.display import display

# ─────────────────────────────────────────────────────────────────────────────
# System / Miscellaneous
# ─────────────────────────────────────────────────────────────────────────────
import os

# %% [markdown]
# ### Loading Data from Local Storage

# %%
cwd = os.getcwd()
print("-"*120)
print("Current Working Directory and contents:\n"+"-"*120)
for root, dirs, files in os.walk(cwd):
    print(f"\nDirectory: {root}")
    print(f"Subdirectories: {dirs}\n"+ "-"*40)
    for file in sorted(files):
        print(f"-> File: {file}")
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Current Working Directory and contents:
# ------------------------------------------------------------------------------------------------------------------------
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis
# Subdirectories: ['images', 'scripts', 'data', 'hpc_scripts']
# ----------------------------------------
# -> File: .DS_Store
# -> File: ImpromptuAnalysis.ipynb
# -> File: filling_weather_with_era5_data.ipynb
# -> File: hitachi_data_retrieval.ipynb
# -> File: initial_data_analysis.ipynb
# -> File: investigating_data_size_and_types.ipynb
# -> File: investigating_era5_world_data.ipynb
# -> File: marginal_emissions_data_prep.ipynb
# -> File: marginal_emissions_log.csv
# -> File: marginal_emissions_model_development.ipynb
# -> File: processing_era5_world_data.ipynb
# -> File: updated_data_analysis.ipynb
# -> File: weather_data_processing.ipynb
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/images
# Subdirectories: ['hitachi']
# ----------------------------------------
# -> File: .DS_Store
# -> File: delhi_customers_map.png
# -> File: mumbai_customers_map.png
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/images/hitachi
# Subdirectories: ['diagrams']
# ----------------------------------------
# -> File: .DS_Store
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/images/hitachi/diagrams
# Subdirectories: []
# ----------------------------------------
# -> File: public_relationship_diagram.png
# -> File: public_schema_diagram.png
# -> File: tiger_relationship_diagram.png
# -> File: tiger_schema_diagram.png
# -> File: topology_relationship_diagram.png
# -> File: topology_schema_diagram.png
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/scripts
# Subdirectories: ['processing_logs']
# ----------------------------------------
# -> File: .DS_Store
# -> File: hitachi_meter_reading_data_retrieval.py
# -> File: hitachi_meter_reading_data_retrieval.sh
# -> File: meter_readings_processing_merge_years.py
# -> File: meter_readings_processing_merge_years.sh
# -> File: meter_readings_processing_split_by_city.py
# -> File: meter_readings_processing_split_by_city.sh
# -> File: meter_readings_processing_split_to_quarterly.py
# -> File: meter_readings_processing_split_to_quarterly.sh
# -> File: meter_readings_standardisation.py
# -> File: meter_readings_standardisation.sh
# -> File: processing_era5_world_data.py
# -> File: reducing_data_size_v2.py
# -> File: reducing_data_size_v2.sh
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/scripts/processing_logs
# Subdirectories: []
# ----------------------------------------
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/data
# Subdirectories: ['hitachi_copy', 'era5']
# ----------------------------------------
# -> File: .DS_Store
# -> File: era5_data.parquet
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/data/hitachi_copy
# Subdirectories: ['meter_primary_files']
# ----------------------------------------
# -> File: .DS_Store
# -> File: customers_20250606_1901.parquet
# -> File: customers_20250630_1215.parquet
# -> File: customers_20250701_1318.parquet
# -> File: customers_20250714_1401.parquet
# -> File: customers_weather_mapping_20250630_1215.parquet
# -> File: grid_and_weather_stacked_20250714_1401.parquet
# -> File: grid_readings_20250606_1901.parquet
# -> File: grid_readings_20250630_1215.parquet
# -> File: grid_readings_20250701_1318.parquet
# -> File: grid_readings_20250714_1401.parquet
# -> File: grid_readings_20250714_1401_half_hourly.parquet
# -> File: grid_readings_20250714_1401_half_hourly_trimmed.parquet
# -> File: grid_readings_20250804_1439.parquet
# -> File: hourly_meter_data_join_with_weather_20250630_1215.parquet
# -> File: hourly_meter_data_with_weather_locations_20250630_1215.parquet
# -> File: meter_readings_20250606_1901.parquet
# -> File: meter_readings_20250630_1215.parquet
# -> File: meter_readings_20250701_1318.parquet
# -> File: weather_20250606_1901.parquet
# -> File: weather_20250630_1215.parquet
# -> File: weather_20250701_1318.parquet
# -> File: weather_20250714_1401.parquet
# -> File: weather_20250714_1401_iso_imputed.parquet
# -> File: weather_20250714_1401_iso_imputed_enriched.parquet
# -> File: weather_20250714_1401_optimised_iso_imputed.parquet
# -> File: weather_20250714_1401_optimised_iso_imputed_enriched.parquet
# -> File: weather_20250714_1401_optimised_iso_imputed_enriched_gap_filled.parquet
# -> File: weather_20250714_1401_optimised_iso_imputed_enriched_gap_filled_half_hourly.parquet
# -> File: weather_20250714_1401_optimised_iso_imputed_enriched_gap_filled_half_hourly_trimmed.parquet
# -> File: weather_imputed_era5_filled.parquet
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/data/hitachi_copy/meter_primary_files
# Subdirectories: []
# ----------------------------------------
# -> File: .DS_Store
# -> File: meter_readings_2021_20250714_2015.parquet
# -> File: meter_readings_2021_20250714_2015_formatted.parquet
# -> File: meter_readings_2021_Q4_20250714_2015_formatted.parquet
# -> File: meter_readings_2022_20250714_2324.parquet
# -> File: meter_readings_2022_20250714_2324_formatted.parquet
# -> File: meter_readings_2022_Q1_20250714_2324_formatted.parquet
# -> File: meter_readings_2022_Q2_20250714_2324_formatted.parquet
# -> File: meter_readings_2022_Q3_20250714_2324_formatted.parquet
# -> File: meter_readings_2022_Q4_20250714_2324_formatted.parquet
# -> File: meter_readings_2023_20250714_2039.parquet
# -> File: meter_readings_2023_20250714_2039_formatted.parquet
# -> File: meter_readings_2023_Q1_20250714_2039_formatted.parquet
# -> File: meter_readings_all_years_20250714_formatted.parquet
# -> File: meter_readings_delhi_2021_20250714_2015_formatted.parquet
# -> File: meter_readings_delhi_2022_20250714_2324_formatted.parquet
# -> File: meter_readings_mumbai_2022_20250714_2324_formatted.parquet
# -> File: meter_readings_mumbai_2023_20250714_2039_formatted.parquet
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/data/era5
# Subdirectories: ['grib_downloads', 'parquets']
# ----------------------------------------
# -> File: .DS_Store
# -> File: era5_reanalysis_data_2020-2025.parquet
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/data/era5/grib_downloads
# Subdirectories: []
# ----------------------------------------
# -> File: 125ae282169904325e8bc153160be150.grib
# -> File: 125ae282169904325e8bc153160be150.grib.47d85.idx
# -> File: 289f2aac241f8a158ff074a66682452e.grib
# -> File: 289f2aac241f8a158ff074a66682452e.grib.47d85.idx
# -> File: 554832a6209258041784298e5401a7ab.grib
# -> File: 554832a6209258041784298e5401a7ab.grib.47d85.idx
# -> File: 5aee58993569287064988fbc8ad385dd.grib
# -> File: 5aee58993569287064988fbc8ad385dd.grib.47d85.idx
# -> File: 5bcc58c42bdde8ce6b147b00099404bc.grib
# -> File: 5bcc58c42bdde8ce6b147b00099404bc.grib.47d85.idx
# -> File: ad36c26a5d6daae43c9aeab1747e078c.grib
# -> File: ad36c26a5d6daae43c9aeab1747e078c.grib.47d85.idx
# -> File: b4eac1bff8a020500806be638e9d4ab9.grib
# -> File: b4eac1bff8a020500806be638e9d4ab9.grib.47d85.idx
# -> File: bc20f736fa82ab5167820d9116ab4859.grib
# -> File: bc20f736fa82ab5167820d9116ab4859.grib.47d85.idx
# -> File: c8a985ffc4908e6597c4498ff596cbad.grib
# -> File: c8a985ffc4908e6597c4498ff596cbad.grib.47d85.idx
# -> File: d1313a3f750d6e7bd89dff34b112d8a8.grib
# -> File: d1313a3f750d6e7bd89dff34b112d8a8.grib.47d85.idx
# -> File: de87f0d77e8aeed868c68ac0daae3dc9.grib
# -> File: de87f0d77e8aeed868c68ac0daae3dc9.grib.47d85.idx
# -> File: e23fa435dfdf294eba51378e96410b31.grib
# -> File: e23fa435dfdf294eba51378e96410b31.grib.47d85.idx
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/data/era5/parquets
# Subdirectories: []
# ----------------------------------------
# -> File: 2020_delhi_era5_reanalysis_single_levels_data.parquet
# -> File: 2020_delhi_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2020_mumbai_era5_reanalysis_single_levels_data.parquet
# -> File: 2020_mumbai_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2021_delhi_era5_reanalysis_single_levels_data.parquet
# -> File: 2021_delhi_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2021_mumbai_era5_reanalysis_single_levels_data.parquet
# -> File: 2021_mumbai_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2022_delhi_era5_reanalysis_single_levels_data.parquet
# -> File: 2022_delhi_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2022_mumbai_era5_reanalysis_single_levels_data.parquet
# -> File: 2022_mumbai_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2023_delhi_era5_reanalysis_single_levels_data.parquet
# -> File: 2023_delhi_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2023_mumbai_era5_reanalysis_single_levels_data.parquet
# -> File: 2023_mumbai_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2024_delhi_era5_reanalysis_single_levels_data.parquet
# -> File: 2024_delhi_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2024_mumbai_era5_reanalysis_single_levels_data.parquet
# -> File: 2024_mumbai_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2025_delhi_era5_reanalysis_single_levels_data.parquet
# -> File: 2025_delhi_era5_reanalysis_single_levels_data_transformed.parquet
# -> File: 2025_mumbai_era5_reanalysis_single_levels_data.parquet
# -> File: 2025_mumbai_era5_reanalysis_single_levels_data_transformed.parquet
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/hpc_scripts
# Subdirectories: ['drafts', 'error_and_output', 'final']
# ----------------------------------------
# -> File: .DS_Store
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/hpc_scripts/drafts
# Subdirectories: []
# ----------------------------------------
# -> File: hitachi_data_retrieval_off_campus_test.py
# -> File: hitachi_data_retrieval_off_campus_test.sh
# -> File: hitachi_meter_reading_retrieval_off_campus.py
# -> File: hitachi_meter_reading_retrieval_off_campus.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_month_v1.py
# -> File: hitachi_meter_reading_retrieval_off_campus_month_v1.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2_2021.py
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2_2022.py
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2_2023.py
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.e618072
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.o618072
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3_2021.py
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3_2022.py
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3_2023.py
# -> File: hitachi_meter_reading_retrieval_off_campus_v2.py
# -> File: hitachi_meter_reading_retrieval_off_campus_v2.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_v3.py
# -> File: hitachi_meter_reading_retrieval_off_campus_v3.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_v4.py
# -> File: hitachi_meter_reading_retrieval_off_campus_v4.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_year_v1.sh
# -> File: hitachi_meter_reading_retrieval_off_campus_year_v1_2021.py
# -> File: hitachi_meter_reading_retrieval_off_campus_year_v1_2022.py
# -> File: hitachi_meter_reading_retrieval_off_campus_year_v1_2023.py
# -> File: hitachi_meter_reading_retrieval_on_campus_v1.py
# -> File: hitachi_meter_reading_retrieval_on_campus_v1.sh
# -> File: hitachi_meter_reading_retrieval_on_campus_year_v1.sh
# -> File: hitachi_meter_reading_retrieval_on_campus_year_v1_2021.py
# -> File: hitachi_meter_reading_retrieval_on_campus_year_v1_2022.py
# -> File: hitachi_meter_reading_retrieval_on_campus_year_v1_2023.py
# -> File: merging_meter_readings_years_v1.py
# -> File: merging_meter_readings_years_v1.sh
# -> File: merging_meter_readings_years_v2.py
# -> File: merging_meter_readings_years_v2.sh
# -> File: meter_data_hourly_aggregation_for_files_v1.py
# -> File: meter_data_hourly_aggregation_for_files_v1.sh
# -> File: meter_data_hourly_aggregation_for_files_v2 copy.py
# -> File: meter_data_hourly_aggregation_for_files_v2 copy.sh
# -> File: meter_data_hourly_aggregation_for_files_v2.py
# -> File: meter_data_hourly_aggregation_for_files_v2.sh
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py
# -> File: meter_data_hourly_aggregation_for_files_v2copy.sh
# -> File: meter_data_hourly_aggregation_for_files_v3.py
# -> File: meter_data_hourly_aggregation_for_files_v3.sh
# -> File: meter_data_hourly_aggregation_for_files_v4.py
# -> File: meter_data_hourly_aggregation_for_files_v4.sh
# -> File: meter_data_hourly_aggregation_for_files_v5 2.sh
# -> File: meter_data_hourly_aggregation_for_files_v5.py
# -> File: meter_data_hourly_aggregation_for_files_v5.sh
# -> File: meter_data_hourly_aggregation_for_files_v6.py
# -> File: meter_data_hourly_aggregation_for_files_v6.sh
# -> File: meter_data_hourly_aggregation_for_files_v7.sh
# -> File: meter_readings_split_city_2022_year_v1.py
# -> File: meter_readings_split_city_2022_year_v1.sh
# -> File: meter_readings_split_city_2022_year_v2.py
# -> File: meter_readings_split_city_2022_year_v2.sh
# -> File: reducing_data_size_v1.py
# -> File: reducing_data_size_v1.sh
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/hpc_scripts/error_and_output
# Subdirectories: []
# ----------------------------------------
# -> File: .DS_Store
# -> File: hitachi_data_retrieval_off_campus_test.e604867
# -> File: hitachi_data_retrieval_off_campus_test.o604867
# -> File: hitachi_meter_Reading_retrieval_off_campus.e604875
# -> File: hitachi_meter_Reading_retrieval_off_campus.o604875
# -> File: hitachi_meter_Reading_retrieval_off_campus_v2.e605381
# -> File: hitachi_meter_Reading_retrieval_off_campus_v2.o605381
# -> File: hitachi_meter_reading_retrieval_off_campus_month_v1.e.e%J
# -> File: hitachi_meter_reading_retrieval_off_campus_month_v1.o607095.o%J
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2.e607501.e%J
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2.o607501.o%J
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.e608349
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.e608349.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.e618072.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.o608349
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.o608349.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v2a.o618072.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e618787
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e618787.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e619754
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e619754.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e620275
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e620275.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e620279
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.e620279.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o618787
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o618787.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o619754
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o619754.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o620275
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o620275.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o620279
# -> File: hitachi_meter_reading_retrieval_off_campus_months_v3.o620279.pbs-7
# -> File: hitachi_meter_reading_retrieval_off_campus_v3.e605657
# -> File: hitachi_meter_reading_retrieval_off_campus_v3.e605671
# -> File: hitachi_meter_reading_retrieval_off_campus_v3.o605657
# -> File: hitachi_meter_reading_retrieval_off_campus_v3.o605671
# -> File: hitachi_meter_reading_retrieval_off_campus_v4.e605688
# -> File: hitachi_meter_reading_retrieval_off_campus_v4.o605688
# -> File: hitachi_meter_reading_retrieval_off_campus_year_v1.o607504.o%J
# -> File: hitachi_meter_reading_retrieval_on_campus_v1.e606148
# -> File: hitachi_meter_reading_retrieval_on_campus_v1.o606148
# -> File: merging_meter_readings_years_v1.py.e618149
# -> File: merging_meter_readings_years_v1.py.e618149.pbs-7
# -> File: merging_meter_readings_years_v1.py.e618670
# -> File: merging_meter_readings_years_v1.py.e618670.pbs-7
# -> File: merging_meter_readings_years_v1.py.o618149
# -> File: merging_meter_readings_years_v1.py.o618149.pbs-7
# -> File: merging_meter_readings_years_v1.py.o618670
# -> File: merging_meter_readings_years_v1.py.o618670.pbs-7
# -> File: merging_meter_readings_years_v2.py.e618707
# -> File: merging_meter_readings_years_v2.py.e618707.pbs-7
# -> File: merging_meter_readings_years_v2.py.o618707
# -> File: merging_meter_readings_years_v2.py.o618707.pbs-7
# -> File: merging_meter_readings_years_v3.py.e619463
# -> File: merging_meter_readings_years_v3.py.e619463.pbs-7
# -> File: merging_meter_readings_years_v3.py.e619755
# -> File: merging_meter_readings_years_v3.py.e619755.pbs-7
# -> File: merging_meter_readings_years_v3.py.o619463
# -> File: merging_meter_readings_years_v3.py.o619463.pbs-7
# -> File: merging_meter_readings_years_v3.py.o619755
# -> File: merging_meter_readings_years_v3.py.o619755.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619281
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619281.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619372
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619372.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619374
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619374.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619376
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619376.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619382
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619382.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619461
# -> File: meter_data_hourly_aggregation_for_files_v1.py.e619461.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619281
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619281.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619372
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619372.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619374
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619374.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619376
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619376.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619382
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619382.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619461
# -> File: meter_data_hourly_aggregation_for_files_v1.py.o619461.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v2.py.e619847
# -> File: meter_data_hourly_aggregation_for_files_v2.py.e619847.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v2.py.o619847
# -> File: meter_data_hourly_aggregation_for_files_v2.py.o619847.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.e619940
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.e619940.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.e619943
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.e619943.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.o619940
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.o619940.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.o619943
# -> File: meter_data_hourly_aggregation_for_files_v2copy.py.o619943.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v2copy.sh.e619937
# -> File: meter_data_hourly_aggregation_for_files_v2copy.sh.o619937
# -> File: meter_data_hourly_aggregation_for_files_v3.e620250
# -> File: meter_data_hourly_aggregation_for_files_v3.e620250.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.e620285
# -> File: meter_data_hourly_aggregation_for_files_v3.e620285.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.o620250
# -> File: meter_data_hourly_aggregation_for_files_v3.o620250.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.o620285
# -> File: meter_data_hourly_aggregation_for_files_v3.o620285.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619965
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619965.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619966
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619966.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619967
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619967.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619972
# -> File: meter_data_hourly_aggregation_for_files_v3.py.e619972.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619965
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619965.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619966
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619966.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619967
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619967.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619972
# -> File: meter_data_hourly_aggregation_for_files_v3.py.o619972.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v4.e623409
# -> File: meter_data_hourly_aggregation_for_files_v4.e623409.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v4.e623476
# -> File: meter_data_hourly_aggregation_for_files_v4.e623476.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v4.o623409
# -> File: meter_data_hourly_aggregation_for_files_v4.o623409.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v4.o623476
# -> File: meter_data_hourly_aggregation_for_files_v4.o623476.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v5.e623574
# -> File: meter_data_hourly_aggregation_for_files_v5.e623574.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v5.e626071
# -> File: meter_data_hourly_aggregation_for_files_v5.e626071.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v5.e631575
# -> File: meter_data_hourly_aggregation_for_files_v5.e631575.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v5.o623574
# -> File: meter_data_hourly_aggregation_for_files_v5.o623574.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v5.o626071
# -> File: meter_data_hourly_aggregation_for_files_v5.o626071.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v5.o631575
# -> File: meter_data_hourly_aggregation_for_files_v5.o631575.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v7.e629220
# -> File: meter_data_hourly_aggregation_for_files_v7.e629220.pbs-7
# -> File: meter_data_hourly_aggregation_for_files_v7.o629220
# -> File: meter_data_hourly_aggregation_for_files_v7.o629220.pbs-7
# -> File: meter_readings_split_by_city.e676157
# -> File: meter_readings_split_by_city.e676157.pbs-7
# -> File: meter_readings_split_by_city.o676157
# -> File: meter_readings_split_by_city.o676157.pbs-7
# -> File: meter_readings_split_by_city_v1.e676185
# -> File: meter_readings_split_by_city_v1.e676185.pbs-7
# -> File: meter_readings_split_by_city_v1.o676185
# -> File: meter_readings_split_by_city_v1.o676185.pbs-7
# -> File: meter_readings_split_city_2022_year_v1.e619075
# -> File: meter_readings_split_city_2022_year_v1.e619075.pbs-7
# -> File: meter_readings_split_city_2022_year_v1.o619075
# -> File: meter_readings_split_city_2022_year_v1.o619075.pbs-7
# -> File: meter_readings_split_city_2022_year_v2.e619077
# -> File: meter_readings_split_city_2022_year_v2.e619077.pbs-7
# -> File: meter_readings_split_city_2022_year_v2.e619079
# -> File: meter_readings_split_city_2022_year_v2.e619079.pbs-7
# -> File: meter_readings_split_city_2022_year_v2.e619794
# -> File: meter_readings_split_city_2022_year_v2.e619794.pbs-7
# -> File: meter_readings_split_city_2022_year_v2.o619077
# -> File: meter_readings_split_city_2022_year_v2.o619077.pbs-7
# -> File: meter_readings_split_city_2022_year_v2.o619079
# -> File: meter_readings_split_city_2022_year_v2.o619079.pbs-7
# -> File: meter_readings_split_city_2022_year_v2.o619794
# -> File: meter_readings_split_city_2022_year_v2.o619794.pbs-7
# -> File: meter_readings_split_to_quarterly_v1.e676292
# -> File: meter_readings_split_to_quarterly_v1.e676292.pbs-7
# -> File: meter_readings_split_to_quarterly_v1.o676292
# -> File: meter_readings_split_to_quarterly_v1.o676292.pbs-7
# -> File: reducing_data_size_v1.e665482
# -> File: reducing_data_size_v1.e665482.pbs-7
# -> File: reducing_data_size_v1.e675911
# -> File: reducing_data_size_v1.e675911.pbs-7
# -> File: reducing_data_size_v1.e675918
# -> File: reducing_data_size_v1.e675918.pbs-7
# -> File: reducing_data_size_v1.e676095
# -> File: reducing_data_size_v1.e676095.pbs-7
# -> File: reducing_data_size_v1.o665482
# -> File: reducing_data_size_v1.o665482.pbs-7
# -> File: reducing_data_size_v1.o675911
# -> File: reducing_data_size_v1.o675911.pbs-7
# -> File: reducing_data_size_v1.o675918
# -> File: reducing_data_size_v1.o675918.pbs-7
# -> File: reducing_data_size_v1.o676095
# -> File: reducing_data_size_v1.o676095.pbs-7
# -> File: reducing_data_size_v2.e676136
# -> File: reducing_data_size_v2.e676136.pbs-7
# -> File: reducing_data_size_v2.e676142
# -> File: reducing_data_size_v2.e676142.pbs-7
# -> File: reducing_data_size_v2.o676136
# -> File: reducing_data_size_v2.o676136.pbs-7
# -> File: reducing_data_size_v2.o676142
# -> File: reducing_data_size_v2.o676142.pbs-7
#
# Directory: /Users/Daniel/Desktop/IRP_WORK_UPDATED/irp-dbk24/code_and_analysis/hpc_scripts/final
# Subdirectories: []
# ----------------------------------------
# -> File: .DS_Store

# %% [markdown]
# ### Defining File Paths

# %%
# Reminder of data directory structure and contents

base_data_directory = "data"  # Base directory where the dataframes will be saved

hitachi_data_directory = os.path.join(base_data_directory, "hitachi_copy")  # Directory where the dataframes will be saved
era5_data_directory = os.path.join(base_data_directory, "era5")  # Directory where

grib_era5_data_directory = os.path.join(era5_data_directory, "grib_downloads")  # Directory where the ERA5 grib files will be saved
parquets_era5_data_directory = os.path.join(era5_data_directory, "parquets")  # Directory where the ERA5 parquet files will be saved

# %%
print("-"*120)
print("[grib_era5_data_directory] and contents:\n"+"-"*120)
for root, dirs, files in os.walk(grib_era5_data_directory):
    print(f"\nDirectory: {root}")
    print(f"Subdirectories: {dirs}\n"+ "-"*40)
    for file in sorted(files):
        print(f"-> File: {file}")
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# [grib_era5_data_directory] and contents:
# ------------------------------------------------------------------------------------------------------------------------
#
# Directory: data/era5/grib_downloads
# Subdirectories: []
# ----------------------------------------
# -> File: 125ae282169904325e8bc153160be150.grib
# -> File: 125ae282169904325e8bc153160be150.grib.47d85.idx
# -> File: 289f2aac241f8a158ff074a66682452e.grib
# -> File: 289f2aac241f8a158ff074a66682452e.grib.47d85.idx
# -> File: 554832a6209258041784298e5401a7ab.grib
# -> File: 554832a6209258041784298e5401a7ab.grib.47d85.idx
# -> File: 5aee58993569287064988fbc8ad385dd.grib
# -> File: 5aee58993569287064988fbc8ad385dd.grib.47d85.idx
# -> File: 5bcc58c42bdde8ce6b147b00099404bc.grib
# -> File: 5bcc58c42bdde8ce6b147b00099404bc.grib.47d85.idx
# -> File: ad36c26a5d6daae43c9aeab1747e078c.grib
# -> File: ad36c26a5d6daae43c9aeab1747e078c.grib.47d85.idx
# -> File: b4eac1bff8a020500806be638e9d4ab9.grib
# -> File: b4eac1bff8a020500806be638e9d4ab9.grib.47d85.idx
# -> File: bc20f736fa82ab5167820d9116ab4859.grib
# -> File: bc20f736fa82ab5167820d9116ab4859.grib.47d85.idx
# -> File: c8a985ffc4908e6597c4498ff596cbad.grib
# -> File: c8a985ffc4908e6597c4498ff596cbad.grib.47d85.idx
# -> File: d1313a3f750d6e7bd89dff34b112d8a8.grib
# -> File: d1313a3f750d6e7bd89dff34b112d8a8.grib.47d85.idx
# -> File: de87f0d77e8aeed868c68ac0daae3dc9.grib
# -> File: de87f0d77e8aeed868c68ac0daae3dc9.grib.47d85.idx
# -> File: e23fa435dfdf294eba51378e96410b31.grib
# -> File: e23fa435dfdf294eba51378e96410b31.grib.47d85.idx

# %%
file1 = "125ae282169904325e8bc153160be150.grib"
file2 = "289f2aac241f8a158ff074a66682452e.grib"
file3 = "554832a6209258041784298e5401a7ab.grib"
file4 = "5aee58993569287064988fbc8ad385dd.grib"
file5 = "5bcc58c42bdde8ce6b147b00099404bc.grib"
file6 = "ad36c26a5d6daae43c9aeab1747e078c.grib"
file7 = "b4eac1bff8a020500806be638e9d4ab9.grib"
file8 = "bc20f736fa82ab5167820d9116ab4859.grib"
file9 = "c8a985ffc4908e6597c4498ff596cbad.grib"
file10 = "d1313a3f750d6e7bd89dff34b112d8a8.grib"
file11 = "de87f0d77e8aeed868c68ac0daae3dc9.grib"
file12 = "e23fa435dfdf294eba51378e96410b31.grib"

# %%
# create list of the files
files = [
    file1, file2, file3, file4, file5,
    file6, file7, file8, file9, file10,
    file11, file12
]

# create full paths for each of the files
grib_files = [os.path.join(grib_era5_data_directory, file) for file in files]

# %% [markdown]
# ### Inspecting files

# %%
def inspect_with_pygrib(path):
    with pygrib.open(path) as grbs:
        msgs = list(grbs)  # load all messages into memory
    # 1) collect unique variable shortNames
    vars_ = sorted({m.shortName for m in msgs})
    # 2) collect all validDates and then get min/max
    dates = sorted({m.validDate for m in msgs})
    t0, t1 = dates[0], dates[-1]
    # 3) get lat/lon bounds from the first message
    lat, lon = msgs[0].latlons()
    lat0, lat1 = float(lat.min()), float(lat.max())
    lon0, lon1 = float(lon.min()), float(lon.max())
    # print summary
    print(f"\nFile: \'{path}\'")
    print(f"\t- Variables: [{', '.join(vars_)}]")
    print(f"\t- Time range: [{t0.isoformat()}]  to  [{t1.isoformat()}]")
    print(f"\t- Latitude:  [{lat0:.3f}]  to  [{lat1:.3f}]")
    print(f"\t- Longitude: [{lon0:.3f}]  to  [{lon1:.3f}]")

# %%
# Example usage
for f in grib_files:
    inspect_with_pygrib(f)
# Out:
# File: 'data/era5/grib_downloads/125ae282169904325e8bc153160be150.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2024-12-31T18:00:00]  to  [2025-07-11T05:00:00]
# 	- Latitude:  [26.000]  to  [30.000]
# 	- Longitude: [75.000]  to  [79.000]
#
# File: 'data/era5/grib_downloads/289f2aac241f8a158ff074a66682452e.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2020-12-31T18:00:00]  to  [2021-12-31T23:00:00]
# 	- Latitude:  [17.000]  to  [21.000]
# 	- Longitude: [70.000]  to  [74.000]
#
# File: 'data/era5/grib_downloads/554832a6209258041784298e5401a7ab.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2023-12-31T18:00:00]  to  [2024-12-31T23:00:00]
# 	- Latitude:  [26.000]  to  [30.000]
# 	- Longitude: [75.000]  to  [79.000]
#
# File: 'data/era5/grib_downloads/5aee58993569287064988fbc8ad385dd.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2023-12-31T18:00:00]  to  [2024-12-31T23:00:00]
# 	- Latitude:  [17.000]  to  [21.000]
# 	- Longitude: [70.000]  to  [74.000]
#
# File: 'data/era5/grib_downloads/5bcc58c42bdde8ce6b147b00099404bc.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2022-12-31T18:00:00]  to  [2023-12-31T23:00:00]
# 	- Latitude:  [26.000]  to  [30.000]
# 	- Longitude: [75.000]  to  [79.000]
#
# File: 'data/era5/grib_downloads/ad36c26a5d6daae43c9aeab1747e078c.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2021-12-31T18:00:00]  to  [2022-12-31T23:00:00]
# 	- Latitude:  [17.000]  to  [21.000]
# 	- Longitude: [70.000]  to  [74.000]
#
# File: 'data/era5/grib_downloads/b4eac1bff8a020500806be638e9d4ab9.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2019-12-31T18:00:00]  to  [2020-12-31T23:00:00]
# 	- Latitude:  [26.000]  to  [30.000]
# 	- Longitude: [75.000]  to  [79.000]
#
# File: 'data/era5/grib_downloads/bc20f736fa82ab5167820d9116ab4859.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2019-12-31T18:00:00]  to  [2020-12-31T23:00:00]
# 	- Latitude:  [17.000]  to  [21.000]
# 	- Longitude: [70.000]  to  [74.000]
#
# File: 'data/era5/grib_downloads/c8a985ffc4908e6597c4498ff596cbad.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2022-12-31T18:00:00]  to  [2023-12-31T23:00:00]
# 	- Latitude:  [17.000]  to  [21.000]
# 	- Longitude: [70.000]  to  [74.000]
#
# File: 'data/era5/grib_downloads/d1313a3f750d6e7bd89dff34b112d8a8.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2020-12-31T18:00:00]  to  [2021-12-31T23:00:00]
# 	- Latitude:  [26.000]  to  [30.000]
# 	- Longitude: [75.000]  to  [79.000]
#
# File: 'data/era5/grib_downloads/de87f0d77e8aeed868c68ac0daae3dc9.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2024-12-31T18:00:00]  to  [2025-07-10T19:00:00]
# 	- Latitude:  [17.000]  to  [21.000]
# 	- Longitude: [70.000]  to  [74.000]
#
# File: 'data/era5/grib_downloads/e23fa435dfdf294eba51378e96410b31.grib'
# 	- Variables: [10u, 10v, 2t, hcc, lcc, mcc, ssr, ssrd, tcc, tp]
# 	- Time range: [2021-12-31T18:00:00]  to  [2022-12-31T23:00:00]
# 	- Latitude:  [26.000]  to  [30.000]
# 	- Longitude: [75.000]  to  [79.000]

# %% [markdown]
# Note:
#
# The city of Delhi is covered by
#  - Latitude:  [26.000]  to  [30.000]
#  - Longitude: [75.000]  to  [79.000]
#
# The city of Mumbai is covered by
#  - Latitude:  [17.000]  to  [21.000]
#  - Longitude: [70.000]  to  [74.000]

# %%
# Copying the values from the above into corresponding file names
file_2025_delhi_raw_filename = "125ae282169904325e8bc153160be150.grib"
file_2021_mumbai_raw_filename = "289f2aac241f8a158ff074a66682452e.grib"
file_2024_delhi_raw_filename = "554832a6209258041784298e5401a7ab.grib"
file_2024_mumbai_raw_filename = "5aee58993569287064988fbc8ad385dd.grib"
file_2023_delhi_raw_filename = "5bcc58c42bdde8ce6b147b00099404bc.grib"
file_2022_mumbai_raw_filename = "ad36c26a5d6daae43c9aeab1747e078c.grib"
file_2020_delhi_raw_filename = "b4eac1bff8a020500806be638e9d4ab9.grib"
file_2020_mumbai_raw_filename = "bc20f736fa82ab5167820d9116ab4859.grib"
file_2023_mumbai_raw_filename = "c8a985ffc4908e6597c4498ff596cbad.grib"
file_2021_delhi_raw_filename = "d1313a3f750d6e7bd89dff34b112d8a8.grib"
file_2025_mumbai_raw_filename = "de87f0d77e8aeed868c68ac0daae3dc9.grib"
file_2022_delhi_raw_filename = "e23fa435dfdf294eba51378e96410b31.grib"

# %%
# creating a list of files
named_files = [file_2025_delhi_raw_filename, file_2024_delhi_raw_filename, file_2023_delhi_raw_filename, file_2022_delhi_raw_filename,
               file_2021_delhi_raw_filename, file_2020_delhi_raw_filename, file_2025_mumbai_raw_filename, file_2024_mumbai_raw_filename,
               file_2023_mumbai_raw_filename, file_2022_mumbai_raw_filename, file_2021_mumbai_raw_filename, file_2020_mumbai_raw_filename]

# creating a list containing full paths for each of the named files
named_filepaths = [os.path.join(grib_era5_data_directory, file) for file in named_files]

# creating a list of names that will be used as keys for a dictionary of the files
dictionary_keys = [
    "2025_delhi_era5_reanalysis_single_levels_data",
    "2024_delhi_era5_reanalysis_single_levels_data",
    "2023_delhi_era5_reanalysis_single_levels_data",
    "2022_delhi_era5_reanalysis_single_levels_data",
    "2021_delhi_era5_reanalysis_single_levels_data",
    "2020_delhi_era5_reanalysis_single_levels_data",
    "2025_mumbai_era5_reanalysis_single_levels_data",
    "2024_mumbai_era5_reanalysis_single_levels_data",
    "2023_mumbai_era5_reanalysis_single_levels_data",
    "2022_mumbai_era5_reanalysis_single_levels_data",
    "2021_mumbai_era5_reanalysis_single_levels_data",
    "2020_mumbai_era5_reanalysis_single_levels_data",
]

# creating a dictionary that maps the keys to the full file paths
named_filepaths_dictionary = dict(zip(dictionary_keys, named_filepaths))

# %%
print("-"*120)
print("Testing named_filepaths_dictionary:\n"+"-"*120)

print("2025 Delhi ERA5 Reanalysis Single Levels Data File Path:")
print("\texpected: [data/era5/grib_downloads/125ae282169904325e8bc153160be150.grib]")
print(f"\tactual: [{named_filepaths_dictionary['2025_delhi_era5_reanalysis_single_levels_data']}]")

print("\n" + "-"*80 + "\n")
print("2023 Mumbai ERA5 Reanalysis Single Levels Data File Path:")
print("\texpected: [data/era5/grib_downloads/c8a985ffc4908e6597c4498ff596cbad.grib]")
print(f"\tactual: [{named_filepaths_dictionary['2023_mumbai_era5_reanalysis_single_levels_data']}]")
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Testing named_filepaths_dictionary:
# ------------------------------------------------------------------------------------------------------------------------
# 2025 Delhi ERA5 Reanalysis Single Levels Data File Path:
# 	expected: [data/era5/grib_downloads/125ae282169904325e8bc153160be150.grib]
# 	actual: [data/era5/grib_downloads/125ae282169904325e8bc153160be150.grib]
#
# --------------------------------------------------------------------------------
#
# 2023 Mumbai ERA5 Reanalysis Single Levels Data File Path:
# 	expected: [data/era5/grib_downloads/c8a985ffc4908e6597c4498ff596cbad.grib]
# 	actual: [data/era5/grib_downloads/c8a985ffc4908e6597c4498ff596cbad.grib]

# %% [markdown]
# ### Investigating Resolution and Granularity

# %%
vars_list = ['10u','10v','2t','hcc','lcc','mcc','ssr','ssrd','tcc','tp']

# %%
# Reminder of the names of the structures:
# list: named_filepaths
# dictionary: named_filepaths_dictionary


# we'll just use the first file as an example
fpath = named_filepaths[0]  # Use the first file as an example

# temporary storage for results of this investigation
records = []
# loop through each variable in the list
for var in vars_list:
    try:
        ds = xr.open_dataset(
            fpath,
            engine="cfgrib",
            backend_kwargs={"filter_by_keys": {"shortName": var}}
        )
    except Exception as e:
        print(f"Skipping {var!r}: {e}")
        continue

    # retrieving spatial coordinates
    lat = ds.latitude.values
    lon = ds.longitude.values

    # flatten valid_time if there's a step dimension
    if "step" in ds.dims and "valid_time" in ds.coords:
        times = np.unique(ds.valid_time.values)
    else:
        times = ds.time.values

    # compute resolutions
    lat_res = np.unique(np.diff(lat)).round(6).tolist()
    lon_res = np.unique(np.diff(lon)).round(6).tolist()

    # temporal resolution in hours
    dt_hrs = (np.diff(times).astype("timedelta64[h]") / np.timedelta64(1, "h")).astype(int)
    time_res = np.unique(dt_hrs).tolist()

    # appending the results to records
    records.append({
        "variable":   var,
        "n_lat":      lat.size,
        "lat_res°":   lat_res,
        "n_lon":      lon.size,
        "lon_res°":   lon_res,
        "n_time":     times.size,
        "time_res_h": time_res,
        "t0":         str(times.min()),
        "t1":         str(times.max()),
    })
    # close the dataset to free resources
    ds.close()
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /opt/homebrew/Caskroom/miniconda/base/envs/irpenv_4/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(

# %%
# build and display the summary table
df = pd.DataFrame(records, columns=[
    "variable","n_lat","lat_res°","n_lon","lon_res°",
    "n_time","time_res_h","t0","t1"
])
display(df)
# Out:
#   variable  n_lat lat_res°  n_lon lon_res°  n_time time_res_h  \
# 0      10u     17  [-0.25]     17   [0.25]    4590        [1]
# 1      10v     17  [-0.25]     17   [0.25]    4590        [1]
# 2       2t     17  [-0.25]     17   [0.25]    4590        [1]
# 3      hcc     17  [-0.25]     17   [0.25]    4590        [1]
# 4      lcc     17  [-0.25]     17   [0.25]    4590        [1]
# 5      mcc     17  [-0.25]     17   [0.25]    4590        [1]
# 6      ssr     17  [-0.25]     17   [0.25]    4596        [1]
# 7     ssrd     17  [-0.25]     17   [0.25]    4596        [1]
# 8      tcc     17  [-0.25]     17   [0.25]    4590        [1]
# 9       tp     17  [-0.25]     17   [0.25]    4596        [1]
#
#                               t0                             t1
# 0  2025-01-01T00:00:00.000000000  2025-07-11T05:00:00.000000000
# 1  2025-01-01T00:00:00.000000000  2025-07-11T05:00:00.000000000
# 2  2025-01-01T00:00:00.000000000  2025-07-11T05:00:00.000000000
# 3  2025-01-01T00:00:00.000000000  2025-07-11T05:00:00.000000000
# 4  2025-01-01T00:00:00.000000000  2025-07-11T05:00:00.000000000
# 5  2025-01-01T00:00:00.000000000  2025-07-11T05:00:00.000000000
# 6  2024-12-31T19:00:00.000000000  2025-07-11T06:00:00.000000000
# 7  2024-12-31T19:00:00.000000000  2025-07-11T06:00:00.000000000
# 8  2025-01-01T00:00:00.000000000  2025-07-11T05:00:00.000000000
# 9  2024-12-31T19:00:00.000000000  2025-07-11T06:00:00.000000000

# %% [markdown]
# ### Summary

# %% [markdown]
# **Data Structure and Resolution**
# - The ERA5-World reanalysis data covers Delhi and Mumbai regions with a spatial resolution of ~0.25 degrees (~30km)
# - This resolution is adequate for regional weather patterns but may miss urban microclimate effects
# - The data contains hourly measurements from 2020-2025, offering high temporal granularity
#
# **Weather Variables**
# - The dataset includes key meteorological variables:
#   - Surface temperature (2t)
#   - Wind components (10u, 10v) - note potential component swapping issue
#   - Cloud cover at different levels (hcc, lcc, mcc, tcc)
#   - Solar radiation (ssr, ssrd)
#   - Precipitation (tp)
#
# **Temporal Considerations**
# - Data requires timezone conversion (UTC to IST, +5.5 hours) for accurate daily pattern analysis
# - Some variables are instantaneous readings (temperature, wind) while others are accumulated (precipitation, radiation)
#
# **Spatial Alignment**
# - Customer locations don't directly align with ERA5 grid points
# - ERA5-Land locations also have a different grid structure
# - Spatial joining methodology needed to match locations to nearest weather data points
#
# **Next Steps**
# - Convert data to parquet format for more efficient storage and retrieval
# - Implement spatial joining methodology for ERA5-Land
# - Use dataset for gap filling
